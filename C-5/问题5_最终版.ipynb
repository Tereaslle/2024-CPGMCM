# %% [markdown]
# ### 问题五 磁性元件的最优化条件
# #### 在磁性元件的设计与优化领域内，磁芯损耗固然是一个不容忽视的核心评价指标，但在工程实践中，为了实现磁性元件整体性能的卓越与最优化，需要综合考虑多个评价指标，其中，传输磁能就是重要的评价指标之一，因此，同时考虑磁芯损耗与传输磁能这二个评价指标，对于指导磁性元件的设计方向、优化其性能表现，具有重要的理论及实践意义。
# #### 请以问题四构建的磁芯损耗预测模型为目标函数，同时考虑传输磁能这个重要指标（由于传输磁能概念的复杂性，我们仅以频率与磁通密度峰值的乘积来衡量传输磁能大小），利用附件一中的实验数据，建立优化模型，分析在什么条件下（温度、频率、波形、磁通密度峰值及磁芯材料），能达到最小的磁芯损耗以及具有最大的传输磁能（即达到最大）？

# %% [markdown]
# #### 我们利用问题4得到的各方程的相应参数进行分析

# %%
import pandas as pd
df = pd.read_excel('../C-4/不同材料不同波形的损耗分离模型和修正方程模型拟合结果.xlsx')
df
# Out:
#            a1        a2        a3        a4            b1   b2        b3  \
# 0    7.368265  1.466915  2.451521 -1.510662  0.000000e+00  1.0  0.000716
# 1   21.558222  1.268477  2.000000 -0.956602  9.714446e-07  1.0  0.000047
# 2    1.279650  1.571948  2.365214 -1.235325  0.000000e+00  1.0  0.000722
# 3    5.992775  1.489006  2.347763 -1.504196  0.000000e+00  1.0  0.000772
# 4    3.729907  1.427762  2.045040 -0.986508  0.000000e+00  1.0  0.000240
# 5    1.061344  1.560109  2.258313 -0.960732  0.000000e+00  1.0  0.000622
# 6    8.169733  1.450616  2.363487 -1.257369  0.000000e+00  1.0  0.000885
# 7    7.370304  1.379933  2.128236 -0.866283  0.000000e+00  1.0  0.000218
# 8    3.702659  1.462162  2.279015 -0.884179  0.000000e+00  1.0  0.000675
# 9   12.744099  1.488247  2.486573 -1.674659  0.000000e+00  1.0  0.000738
# 10  71.430842  1.180964  2.000000 -0.899322  4.327462e-06  1.0  0.000000
# 11  30.324620  1.343432  2.427418 -1.197556  0.000000e+00  1.0  0.001477
#
#               b4 励磁波形   材料        损耗分离模型    修正斯坦麦茨方程损失         a         b  \
# 0   3.616264e-08  正弦波  材料1  6.777555e+12  1.447990e+11  0.989870  0.012022
# 1   1.504900e-03  三角波  材料1  2.372132e+13  9.638618e+12  0.886876  0.119129
# 2   1.059254e-07  梯形波  材料1  9.528959e+12  2.583470e+11  0.988585  0.012312
# 3   3.506102e-07  正弦波  材料2  6.540775e+12  2.336712e+11  0.976362  0.029161
# 4   1.055987e-03  三角波  材料2  3.862614e+13  8.879885e+12  0.972753  0.029820
# 5   1.077684e-04  梯形波  材料2  2.835746e+13  1.460342e+12  0.975413  0.027418
# 6   0.000000e+00  正弦波  材料3  9.048098e+12  2.825606e+11  0.975241  0.032249
# 7   1.457908e-03  三角波  材料3  5.211616e+13  9.251303e+12  0.972535  0.030808
# 8   2.440311e-04  梯形波  材料3  6.240959e+13  1.943241e+12  0.980420  0.022612
# 9   0.000000e+00  正弦波  材料4  9.800750e+11  4.424592e+10  0.960501  0.048447
# 10  2.352982e-03  三角波  材料4  2.132972e+13  2.568792e+12  0.968270  0.037729
# 11  0.000000e+00  梯形波  材料4  3.580545e+12  4.014728e+10  0.999999  0.000000
#
#             cost
# 0   1.439728e+11
# 1   9.391422e+12
# 2   2.570124e+11
# 3   2.290826e+11
# 4   8.854254e+12
# 5   1.441215e+12
# 6   2.751386e+11
# 7   9.212791e+12
# 8   1.915290e+12
# 9   4.228244e+10
# 10  2.544656e+12
# 11  4.014728e+10

# %% [markdown]
# ### $P_{总损耗}$=$\alpha  P_{修正斯坦麦茨方程}+\beta P_{损耗分离模型}$
#
# #### 修正的斯坦麦茨方程$P_{修正斯坦麦茨方程}=a1•f^{a2}•B_m^{a3}•log(T)^{a4}$
#
# #### 损耗分离模型$P_{损耗分离模型}=P_{h}+P_{cl}+P_{e} .$
# * $P_h=b1•f•B_m^{b2} $
# * $P_{cl}=b3•f^2•B_m^2$
# * $P_e=8•\sqrt{\sigma\cdot S\cdot G\cdot V_0}•f^{1.5}•B_m^{1.5}$

# %% [markdown]
# #### 在不同的材料不同的波形情况下，我们可以得到不同参数的总方程，同学们可以基于得到的总方程进行公式推导，这里一共总共是3个自变量* * 包括频率、磁通密度峰值、温度
# #### 同学们可以根据不同系数条件下，对这三个变量求偏导，令偏导＝0，得到最优条件

# %% [markdown]
# #### 在这里我们考虑利用遗传算法进行最优条件选择

# %%
def ensemble(x):
    return a*steinmetz_eq_adjust(x) + b*separate(x)

def separate(x):
    return b1*x[0]*x[1]**b2+b3*x[0]**2*x[1]**2+(b4*0.1356)**0.5*x[0]**1.5*x[1]**1.5

def steinmetz_eq_adjust(x):
    return a1 * x[0]**a2 * x[1]**a3 * np.log(x[2])**a4

# %%
import numpy as np
import matplotlib.pyplot as plt

import rasterio
import matplotlib.pyplot as plt
from rasterio.plot import show
import numpy as np
import matplotlib.colors as mcolors
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd
import warnings
import seaborn as sns
from scipy.stats import pearsonr
# 忽略所有的警告
warnings.filterwarnings("ignore")

# 设置字体为 SimHei（黑体）以支持中文
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用黑体显示中文
plt.rcParams['axes.unicode_minus'] = False    # 解决负号


# 定义目标函数 (例如 f(x) = x^2 + y^2)
def objective_function(x):
    return a*steinmetz_eq_adjust(x) + b*separate(x)

# 粒子类
class Particle:
    def __init__(self, dimensions, bounds):
        self.position = np.random.uniform(bounds[:, 0], bounds[:, 1], dimensions)  # 粒子的位置
        self.velocity = np.random.uniform(-1, 1, dimensions)                      # 粒子的速度
        self.best_position = np.copy(self.position)                               # 粒子经历的最佳位置
        self.best_score = float('inf')                                            # 粒子经历的最佳得分
        self.bounds = bounds                                                     # 搜索空间边界

    # 更新位置并确保其在边界范围内
    def update_position(self):
        self.position = np.clip(self.position, self.bounds[:, 0], self.bounds[:, 1])

# 粒子群算法类
class PSO:
    def __init__(self, objective_function, dimensions, bounds, n_particles=30, max_iter=100, w=0.5, c1=1.5, c2=2.0):
        self.objective_function = objective_function  # 目标函数
        self.dimensions = dimensions                  # 搜索空间的维度
        self.bounds = bounds                          # 搜索空间的边界 (约束)
        self.n_particles = n_particles                # 粒子的数量
        self.max_iter = max_iter                      # 最大迭代次数
        self.w = w                                    # 惯性权重
        self.c1 = c1                                  # 个体学习因子
        self.c2 = c2                                  # 社会学习因子
        self.particles = [Particle(dimensions, bounds) for _ in range(n_particles)]  # 初始化粒子群
        self.global_best_position = np.zeros(dimensions)  # 全局最佳位置
        self.global_best_score = float('inf')             # 全局最佳得分

    # 优化过程
    def optimize(self):
        ls = []
        for t in range(self.max_iter):
            for particle in self.particles:
                # 计算当前粒子的目标函数值
                fitness = self.objective_function(particle.position)
                
                # 更新粒子的个体最佳位置和得分
                if fitness < particle.best_score:
                    particle.best_score = fitness
                    particle.best_position = np.copy(particle.position)

                # 更新全局最佳位置和得分
                if fitness < self.global_best_score:
                    self.global_best_score = fitness
                    self.global_best_position = np.copy(particle.position)

            # 更新粒子的速度和位置
            for particle in self.particles:
                r1 = np.random.random(self.dimensions)
                r2 = np.random.random(self.dimensions)

                # 速度更新公式
                particle.velocity = (self.w * particle.velocity +
                                    self.c1 * r1 * (particle.best_position - particle.position) +
                                    self.c2 * r2 * (self.global_best_position - particle.position))

                # 位置更新
                particle.position += particle.velocity
                particle.update_position()  # 更新后确保粒子位置在约束范围内

            # 输出当前迭代的全局最优解
            print(f"Iteration {t+1}/{self.max_iter}, Best Position: {self.global_best_position}, Best Score: {self.global_best_score}")
            ls.append(self.global_best_score)

        return self.global_best_position, self.global_best_score,pd.Series(ls)


# 定义问题的维度
dimensions = 3
# 定义每个维度的搜索空间边界（例如 [-5, 5]）
bounds = np.array([[49990, 501180], [0.00963815,0.313284469], [25, 90]])


ls = []
score = []
mat = []
bo = []

plt.figure(figsize=(16, 12))

for i,material_type in enumerate(df['材料'].unique()):
    
    plt.subplot(2,2,i+1)
    plt.title(f'{material_type}',fontsize=15)
    if i >= 2:
        plt.xlabel('迭代次数',fontsize=18)
    if i % 2 == 0:
        plt.ylabel('目标函数（磁芯损耗）',fontsize=18)
    for oi, o in enumerate(df['励磁波形'].unique()):
        a1,a2,a3,a4,b1,b2,b3,b4,a,b = df[(df.材料==material_type)&(df.励磁波形==o)][['a1', 'a2', 'a3', 'a4', 'b1', 'b2', 'b3', 'b4','a','b']].values[0]
        pso = PSO(objective_function, dimensions, bounds, n_particles=5, max_iter=15)
        best_position, best_score,values = pso.optimize()
        
        values.plot(linestyle='-',marker='*',markerfacecolor='#FF9933',alpha=0.7,linewidth=5,label=f'{o}')
        
        ls.append(best_position)
        score.append(best_score)
        mat.append(i)
        bo.append(o)
    
    plt.legend()
    plt.xticks(list(range(15)),list(range(1,16)),rotation=0, fontsize=11)
plt.suptitle('不同材料励磁波形的粒子群优化迭代过程',fontsize=20,y=0.92)
plt.savefig(f'./不同材料励磁波形的粒子群优化迭代过程.png',dpi=500)
plt.show()
result = pd.DataFrame(ls,columns=['f_opt','Bm_opt','temp_opt'])
result['材料'] = mat
result['励磁波形'] = bo
result['最优磁芯损耗'] = score
result.to_excel('最优磁芯损耗.xlsx',index=False)
# Out:
# Iteration 1/15, Best Position: [8.67659764e+04 6.03760429e-02 4.67152678e+01], Best Score: 17412.574047419446
# Iteration 2/15, Best Position: [8.67659764e+04 6.03760429e-02 4.67152678e+01], Best Score: 17412.574047419446
# Iteration 3/15, Best Position: [8.67659764e+04 6.03760429e-02 4.67152678e+01], Best Score: 17412.574047419446
# Iteration 4/15, Best Position: [4.99900000e+04 9.63815000e-03 4.41456457e+01], Best Score: 89.06870158165134
# Iteration 5/15, Best Position: [4.99900000e+04 9.63815000e-03 6.39547557e+01], Best Score: 77.61505014687239
# Iteration 6/15, Best Position: [4.99900000e+04 9.63815000e-03 8.44727682e+01], Best Score: 70.56714103466035
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 69.1135717625979
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 69.1135717625979
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 69.1135717625979
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 69.1135717625979
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 69.1135717625979
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 69.1135717625979
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 69.1135717625979
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 69.1135717625979
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 69.1135717625979
# Iteration 1/15, Best Position: [3.77447539e+05 4.41140077e-02 3.25490416e+01], Best Score: 138967.11337476768
# Iteration 2/15, Best Position: [3.52921611e+05 9.63815000e-03 3.18471491e+01], Best Score: 6301.0436594574585
# Iteration 3/15, Best Position: [3.52921611e+05 9.63815000e-03 3.18471491e+01], Best Score: 6301.0436594574585
# Iteration 4/15, Best Position: [2.19289422e+05 9.63815000e-03 3.69837009e+01], Best Score: 3288.0782396723357
# Iteration 5/15, Best Position: [7.83441325e+04 9.63815000e-03 4.29755513e+01], Best Score: 845.915591145335
# Iteration 6/15, Best Position: [4.99900000e+04 9.63815000e-03 4.85540635e+01], Best Score: 462.2111863288726
# Iteration 7/15, Best Position: [4.99900000e+04 9.63815000e-03 5.41245738e+01], Best Score: 450.6747383480911
# Iteration 8/15, Best Position: [4.99900000e+04 9.63815000e-03 5.77882696e+01], Best Score: 444.00991386579165
# Iteration 9/15, Best Position: [4.99900000e+04 9.63815000e-03 6.02920587e+01], Best Score: 439.8051179154064
# Iteration 10/15, Best Position: [4.99900000e+04 9.63815000e-03 6.44925779e+01], Best Score: 433.3004907693695
# Iteration 11/15, Best Position: [4.99900000e+04 9.63815000e-03 6.94663088e+01], Best Score: 426.3599390603468
# Iteration 12/15, Best Position: [4.99900000e+04 9.63815000e-03 7.41501433e+01], Best Score: 420.45740062707307
# Iteration 13/15, Best Position: [4.99900000e+04 9.63815000e-03 7.64920605e+01], Best Score: 417.70568712705085
# Iteration 14/15, Best Position: [4.99900000e+04 9.63815000e-03 8.00233289e+01], Best Score: 413.7798218701615
# Iteration 15/15, Best Position: [4.99900000e+04 9.63815000e-03 8.99246545e+01], Best Score: 403.98951039954335
# Iteration 1/15, Best Position: [1.15911576e+05 4.49230047e-02 5.64536423e+01], Best Score: 13645.71785946302
# Iteration 2/15, Best Position: [4.99900000e+04 9.63815000e-03 5.29523389e+01], Best Score: 97.70872007782567
# Iteration 3/15, Best Position: [4.9990000e+04 9.6381500e-03 5.4847928e+01], Best Score: 96.6722118551969
# Iteration 4/15, Best Position: [4.99900000e+04 9.63815000e-03 6.12404993e+01], Best Score: 93.55136902267249
# Iteration 5/15, Best Position: [4.99900000e+04 9.63815000e-03 7.42235893e+01], Best Score: 88.53374376969008
# Iteration 6/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 83.98274564477127
# Iteration 1/15, Best Position: [3.31556935e+05 2.71224261e-02 6.80242917e+01], Best Score: 25194.641487711233
# Iteration 2/15, Best Position: [1.89881828e+05 9.63815000e-03 6.06447934e+01], Best Score: 1011.8965632303665
# Iteration 3/15, Best Position: [4.99900000e+04 9.63815000e-03 5.12874579e+01], Best Score: 141.90209075978058
# Iteration 4/15, Best Position: [4.99900000e+04 9.63815000e-03 8.39068147e+01], Best Score: 119.71882606841497
# Iteration 5/15, Best Position: [4.99900000e+04 9.63815000e-03 8.57238453e+01], Best Score: 118.8913849927264
# Iteration 6/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 117.04791986437097
# Iteration 1/15, Best Position: [6.59058389e+04 1.37037968e-01 6.67285055e+01], Best Score: 115674.17912365704
# Iteration 2/15, Best Position: [4.99900000e+04 9.63815000e-03 6.65590763e+01], Best Score: 345.1646785880801
# Iteration 3/15, Best Position: [4.99900000e+04 9.63815000e-03 7.87883455e+01], Best Score: 332.21567476044777
# Iteration 4/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 5/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 6/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 322.6823661420773
# Iteration 1/15, Best Position: [4.12655785e+05 4.52905406e-02 7.24101919e+01], Best Score: 142355.51364068245
# Iteration 2/15, Best Position: [3.67065867e+05 9.63815000e-03 7.15664406e+01], Best Score: 3688.2684623447785
# Iteration 3/15, Best Position: [3.17630153e+05 9.63815000e-03 6.37023147e+01], Best Score: 3006.9270794901013
# Iteration 4/15, Best Position: [2.89865549e+05 9.63815000e-03 6.05938574e+01], Best Score: 2630.3727705340893
# Iteration 5/15, Best Position: [2.37814291e+05 9.63815000e-03 5.51420728e+01], Best Score: 1964.7046326874322
# Iteration 6/15, Best Position: [1.53871872e+05 9.63815000e-03 5.14297449e+01], Best Score: 1004.4070137123579
# Iteration 7/15, Best Position: [4.99900000e+04 9.63815000e-03 4.60757485e+01], Best Score: 175.95905091665068
# Iteration 8/15, Best Position: [4.99900000e+04 9.63815000e-03 4.79741479e+01], Best Score: 174.24612773491904
# Iteration 9/15, Best Position: [4.99900000e+04 9.63815000e-03 4.90552808e+01], Best Score: 173.31558912659102
# Iteration 10/15, Best Position: [4.99900000e+04 9.63815000e-03 5.13208359e+01], Best Score: 171.46203682643485
# Iteration 11/15, Best Position: [4.9990000e+04 9.6381500e-03 5.5079034e+01], Best Score: 168.64285310432624
# Iteration 12/15, Best Position: [4.99900000e+04 9.63815000e-03 5.96594838e+01], Best Score: 165.57128751710079
# Iteration 13/15, Best Position: [4.99900000e+04 9.63815000e-03 6.42548575e+01], Best Score: 162.82168613526477
# Iteration 14/15, Best Position: [4.99900000e+04 9.63815000e-03 6.78079981e+01], Best Score: 160.88668812559703
# Iteration 15/15, Best Position: [4.99900000e+04 9.63815000e-03 7.19017391e+01], Best Score: 158.83356907341442
# Iteration 1/15, Best Position: [5.95077999e+04 5.54679004e-02 5.52276375e+01], Best Score: 12911.344440312358
# Iteration 2/15, Best Position: [5.95077999e+04 5.54679004e-02 5.52276375e+01], Best Score: 12911.344440312358
# Iteration 3/15, Best Position: [4.99900000e+04 9.63815000e-03 5.54597878e+01], Best Score: 162.81609185172914
# Iteration 4/15, Best Position: [4.99900000e+04 9.63815000e-03 7.12493527e+01], Best Score: 151.37200414141077
# Iteration 5/15, Best Position: [4.99900000e+04 9.63815000e-03 8.74056263e+01], Best Score: 143.10147668555112
# Iteration 6/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 141.98698390194633
# Iteration 1/15, Best Position: [3.69868145e+05 7.06256110e-02 8.52120277e+01], Best Score: 343697.15728343313
# Iteration 2/15, Best Position: [3.69868145e+05 7.06256110e-02 8.52120277e+01], Best Score: 343697.15728343313
# Iteration 3/15, Best Position: [3.77057183e+05 9.63815000e-03 9.00000000e+01], Best Score: 5127.633779190563
# Iteration 4/15, Best Position: [2.66762677e+05 9.63815000e-03 8.58117071e+01], Best Score: 3196.1889734090646
# Iteration 5/15, Best Position: [1.42001685e+05 9.63815000e-03 8.81413245e+01], Best Score: 1324.4735647933549
# Iteration 6/15, Best Position: [4.99900000e+04 9.63815000e-03 8.94855813e+01], Best Score: 310.6689652712964
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 310.33288264435345
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 310.33288264435345
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 310.33288264435345
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 310.33288264435345
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 310.33288264435345
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 310.33288264435345
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 310.33288264435345
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 310.33288264435345
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 310.33288264435345
# Iteration 1/15, Best Position: [8.55685200e+04 1.83112078e-01 6.08998500e+01], Best Score: 357846.69507676177
# Iteration 2/15, Best Position: [7.51784158e+04 9.63815000e-03 5.63534169e+01], Best Score: 373.37582395420515
# Iteration 3/15, Best Position: [4.99900000e+04 9.63815000e-03 5.62405118e+01], Best Score: 204.80336630386188
# Iteration 4/15, Best Position: [4.99900000e+04 9.63815000e-03 5.62405118e+01], Best Score: 204.80336630386188
# Iteration 5/15, Best Position: [4.99900000e+04 9.63815000e-03 6.13710161e+01], Best Score: 201.05105827609682
# Iteration 6/15, Best Position: [4.99900000e+04 9.63815000e-03 8.65977985e+01], Best Score: 187.60457985848655
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 186.22061350213352
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 186.22061350213352
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 186.22061350213352
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 186.22061350213352
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 186.22061350213352
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 186.22061350213352
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 186.22061350213352
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 186.22061350213352
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 186.22061350213352
# Iteration 1/15, Best Position: [7.43919612e+04 7.07625942e-02 8.70045001e+01], Best Score: 25505.00174947581
# Iteration 2/15, Best Position: [7.43923821e+04 9.63815000e-03 8.66031134e+01], Best Score: 191.07904220140637
# Iteration 3/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 4/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 5/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 6/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 102.51060474078237
# Iteration 1/15, Best Position: [2.45629555e+05 4.03082931e-02 8.67148001e+01], Best Score: 68616.58965429662
# Iteration 2/15, Best Position: [1.25225117e+05 9.63815000e-03 9.00000000e+01], Best Score: 1768.5688951429431
# Iteration 3/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 4/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 5/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 6/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 595.4948422713111
# Iteration 1/15, Best Position: [4.68615775e+05 1.81648055e-02 6.82121402e+01], Best Score: 13347.647535284983
# Iteration 2/15, Best Position: [4.68615872e+05 9.63815000e-03 6.78568906e+01], Best Score: 2870.3370068496233
# Iteration 3/15, Best Position: [2.77418654e+05 9.63815000e-03 6.88148584e+01], Best Score: 1413.61989823997
# Iteration 4/15, Best Position: [1.53102411e+05 9.63815000e-03 7.94120179e+01], Best Score: 611.2341375473285
# Iteration 5/15, Best Position: [4.99900000e+04 9.63815000e-03 8.93348634e+01], Best Score: 131.6297144421928
# Iteration 6/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
# Iteration 7/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
# Iteration 8/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
# Iteration 9/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
# Iteration 10/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
# Iteration 11/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
# Iteration 12/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
# Iteration 13/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
# Iteration 14/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
# Iteration 15/15, Best Position: [4.99900e+04 9.63815e-03 9.00000e+01], Best Score: 131.3699000933652
